# %% [markdown]
# # Data Wrangling - La cirugía de los datos
#
# El data wrannggling, a veces denominado data munging, es el proceso de transformar y mapear datos de un dataset raw (en bruto) en otro formato con la intención de hacerlo más apropiado y valioso para una variedad de propósitos posteriores, como en análisis. Un data wrangler es una persona que realiza estas operaciones de transformación.
#
# Esto puede incluir munging, visualización de datos, agregación de datos, entrenamiento de un modelo estadístico, así como muchos otros usos potenciales. La oscilación de datos como proceso generalmente sigue un conjunto de pasos generales que comienzan extrayendo los datos en forma cruda del origen de datos, dividiendo los datos en bruto usando algoritmos (por ejemplo, clasificación) o análizando los datos en estructuras de datos predefinidas, y finalmente depositando el contenido resultante en un sistema de almacenamiento (o silo) para su uso futuro.

# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/hecag/Documents/GitHub/python-ml-course/datasets/customer-churn-model/Customer Churn Model.txt")

# %%
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %% [markdown]
# ## Crear un subconjunto de datos

# %%
account_lenght = data["Account Length"]

# %%
account_lenght.head()
# Out:
# 0    128
# 1    107
# 2    137
# 3     84
# 4     75
# Name: Account Length, dtype: int64

# %%
type(account_lenght)
# Out:
# pandas.core.series.Series

# %%
subset = data[["Account Length", "Phone", "Eve Charge", "Day Calls"]]

# %%
subset.head()
# Out:
#    Account Length     Phone  Eve Charge  Day Calls
# 0             128  382-4657       16.78        110
# 1             107  371-7191       16.62        123
# 2             137  358-1921       10.30        114
# 3              84  375-9999        5.26         71
# 4              75  330-6626       12.61        113

# %%
type(subset)
# Out:
# pandas.core.frame.DataFrame

# %%
desired_columns = ["Account Length", "Phone", "Eve Charge", "Night Calls"]
subset = data[desired_columns]
subset.head()
# Out:
#    Account Length     Phone  Eve Charge  Night Calls
# 0             128  382-4657       16.78           91
# 1             107  371-7191       16.62          103
# 2             137  358-1921       10.30          104
# 3              84  375-9999        5.26           89
# 4              75  330-6626       12.61          121

# %%
undesired_columns = ["Account Length", "Vmail Message", "Day Calls"]
undesired_columns
# Out:
# ['Account Length', 'Vmail Message', 'Day Calls']

# %%
all_columns_list = data.columns.values.tolist()
all_columns_list
# Out:
# ['State',
#  'Account Length',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'VMail Message',
#  'Day Mins',
#  'Day Calls',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
sublist = [x for x in all_columns_list if x not in undesired_columns]
sublist
# Out:
# ['State',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'VMail Message',
#  'Day Mins',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
subset = data[sublist]
subset.head()
# Out:
#   State  Area Code     Phone Int'l Plan VMail Plan  VMail Message  Day Mins  \
# 0    KS        415  382-4657         no        yes             25     265.1
# 1    OH        415  371-7191         no        yes             26     161.6
# 2    NJ        415  358-1921         no         no              0     243.4
# 3    OH        408  375-9999        yes         no              0     299.4
# 4    OK        415  330-6626        yes         no              0     166.7
#
#    Day Charge  Eve Mins  Eve Calls  Eve Charge  Night Mins  Night Calls  \
# 0       45.07     197.4         99       16.78       244.7           91
# 1       27.47     195.5        103       16.62       254.4          103
# 2       41.38     121.2        110       10.30       162.6          104
# 3       50.90      61.9         88        5.26       196.9           89
# 4       28.34     148.3        122       12.61       186.9          121
#
#    Night Charge  Intl Mins  Intl Calls  Intl Charge  CustServ Calls  Churn?
# ...

# %% [markdown]
# ### Filtrado alternativo

# %%
a = set(undesired_columns)
b = set(all_columns_list)
sublist = b-a
sublist = list(sublist)
sublist
# Out:
# ['Area Code',
#  'Day Mins',
#  'Night Mins',
#  'Day Charge',
#  'Night Calls',
#  'VMail Plan',
#  'Eve Charge',
#  'VMail Message',
#  'Intl Charge',
#  'Night Charge',
#  'Intl Calls',
#  'State',
#  'Eve Mins',
#  "Int'l Plan",
#  'Phone',
#  'CustServ Calls',
#  'Intl Mins',
#  'Churn?',
#  'Eve Calls']

# %%
data[:8]
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
# 5    AL             118        510  391-8027        yes         no
# 6    MA             121        510  355-9993         no        yes
# 7    MO             147        415  329-9001        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# ...

# %%
data[3330:]
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 3330    RI              28        510  328-8230         no         no
# 3331    CT             184        510  364-6381        yes         no
# 3332    TN              74        415  400-4344         no        yes
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# 3330              0     180.8        109       30.74  ...         58
# 3331              0     213.8        105       36.35  ...         84
# 3332             25     234.4        113       39.85  ...         82
#
#       Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  \
# 3330       24.55       191.9           91          8.64       14.1
# 3331       13.57       139.2          137          6.26        5.0
# 3332       22.60       241.4           77         10.86       13.7
#
#       Intl Calls  Intl Charge  CustServ Calls  Churn?
# 3330           6         3.81               2  False.
# ...

# %% [markdown]
# ## Condiciones

# %%
##Usuarios con Day Mins > 500
data1 = data[data["Day Mins"]>300]
data1.shape
# Out:
# (43, 21)

# %%
##Usuarios de Nueva York (State = "NY")
data2 = data[data["State"]=="NY"]
data2.shape
# Out:
# (83, 21)

# %%
##AND -> &
data3 = data[(data["Day Mins"]>300) & (data["State"]=="NY")]
data3.shape
# Out:
# (2, 21)

# %%
##OR -> |
data4 = data[(data["Day Mins"]>300) | (data["State"]=="NY")]
data4.shape
# Out:
# (124, 21)

# %%
data5 = data[data["Day Calls"] < data["Night Calls"]]
data5.shape
# Out:
# (1626, 21)

# %%
data5 = data[data["Day Mins"] < data["Night Mins"]]
data5.shape
# Out:
# (2051, 21)
